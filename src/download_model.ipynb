# %%
from modelscope import snapshot_download

model_dir = snapshot_download(
    model_id="hfl/chinese-macbert-base",
    local_dir="../models/chinese-macbert-base",
)

print(f"模型已下载至：{model_dir}")
# Out:
# 2026-08-18 16:22:29,395 | INFO    | modelscope_hub.download | Downloading 12 files from hfl/chinese-macbert-base@master
# Downloading: 100%|██████████| 12/12 [00:00<00:00, 27.50file/s]
# 模型已下载至：../models/chinese-macbert-base
